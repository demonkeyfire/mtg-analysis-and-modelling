# %% [markdown]
# ## Python Libraries

# %%
import json
import os
import pandas as pd

# %% [markdown]
# ## Functions

# %%
# Function for reading in the AllPrintings.json
def all_printings_read(path, file):

    """
    Load a JSON file from the given path, print its metadata, and return its content.

    Args:
        path (str): Directory containing the JSON file.
        file (str): JSON filename to load.

    Returns:
        dict: Parsed JSON data.
    """

    # Complete file path
    path = f'{path}/{file}'

    # Reading in json file
    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # Print the meta values of the file
    print(f"Filename = {os.path.basename(path)}")
    print(f"Version = {data['meta']['version']} | Date = {data['meta']['date']}")

    # Return the json file
    return data

# %%
# Function for printing the hierarchy of a dictionary with element lengths
def print_dict_structure(data, indent=0, max_depth=None):
    """
    Recursively prints the hierarchical structure of a dictionary or list,
    including the length of each element where applicable.

    Args:
        data: The dictionary or list to explore.
        indent: Current indentation level (used internally).
        max_depth: Limit how deep to traverse (None for full depth).

    Prints:
        Hierarchical structure with type and length (if measurable).
    """
    prefix = "  " * indent

    if isinstance(data, dict):
        for key, value in data.items():
            length_info = f", len={len(value)}" if hasattr(value, "__len__") and not isinstance(value, (str, bytes)) else ""
            print(f"{prefix}{key} ({type(value).__name__}{length_info})")
            if max_depth is None or indent < max_depth - 1:
                print_dict_structure(value, indent + 1, max_depth)

    elif isinstance(data, list):
        if data and (max_depth is None or indent < max_depth - 1):
            print_dict_structure(data[0], indent + 1, max_depth)

    else:
        length_info = f", len={len(data)}" if hasattr(data, "__len__") and not isinstance(data, (str, bytes)) else ""
        print(f"{prefix}{type(data).__name__}{length_info}")

# %% [markdown]
# ## Main Code

# %%
# Reading the MTGJSON all sets JSON file
data__all_printings = all_printings_read('/mnt/e/Projects/MTG/json','AllPrintings.json')
# Out:
# Filename = AllPrintings.json
# Version = 5.2.2+20250803 | Date = 2025-08-03

# %%
print_dict_structure(data__all_printings['data']['10E'], max_depth=10)
# Out:
# baseSetSize (int)
#   int
# block (str)
#   str
# booster (dict, len=1)
#   draft (dict, len=5)
#     boosters (list, len=16)
#         contents (dict, len=4)
#           basic (int)
#             int
#           common (int)
#             int
#           rare (int)
#             int
#           uncommon (int)
#             int
#         weight (int)
#           int
#     boostersTotalWeight (int)
#       int
#     name (str)
#       str
#     sheets (dict, len=8)
#       basic (dict, len=3)
#         cards (dict, len=20)
#           053c8559-8ab8-5a1a-9444-6140b41470c4 (int)
#             int
#           06ac124d-5c6e-542e-bf11-552ec9cc19cc (int)
#             int
#           0f0aa930-854b-59fb-bd76-69d987356f90 (int)
#             int
#           2e21d91d-3970-503f-b36a-e2b0e37fb3ee (int)
#             int
#           31bd4e75-e2c5-5252-a7ff-4eb2a99a4a44 (int)
#             int
#           3d407269-4586-51e3-9da6-298d65aff831 (int)
#             int
#           3e12f3ab-96ab-5d5a-8bed-92b37ffee9aa (int)
#             int
#           3e951ede-39fc-58c6-8a89-e2c320902ddd (int)
#             int
#           47e1bdab-e112-526d-bd9f-7f1cffef7187 (int)
#             int
#           4a17c998-1a44-5537-b675-b19522d43bee (int)
#             int
#           4b3673bc-4f31-5877-9710-44d875dcca8a (int)
#             int
#           4d710f8c-6249-5877-9799-edf65d0c3e68 (int)
#             int
#           6c88ef33-31c8-545f-96dc-de46d68bdbc9 (int)
#             int
#           77977762-e1e1-507b-8d59-e9ed6671a926 (int)
#             int
#           87d6bcfb-0e75-59f7-be6c-30aa7c344ccb (int)
#             int
#           a494d14e-b4c3-5467-8af5-bad8b41da09a (int)
#             int
#           c1f98960-ef31-5ec9-af8d-d6d56169047b (int)
#             int
#           c4823642-08dd-5c10-ae26-ef8d52cf3a43 (int)
#             int
#           ec72e59f-bc37-50fd-a1b5-3afac5a402b3 (int)
#             int
#           eedae11d-cb7c-5b59-bcdd-419e3d6311a1 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       common (dict, len=4)
#         balanceColors (bool)
#           bool
#         cards (dict, len=121)
#           004adf9a-b59a-5d56-9093-df73b9929bb1 (int)
#             int
#           01248698-729b-5a69-ba8c-f1686a181abb (int)
#             int
#           02aa05a4-ff94-5bda-8ad7-24f00bd19ec4 (int)
#             int
#           02e23fa1-b2f0-528c-b331-12a0c27bc5eb (int)
#             int
#           033917bc-01f6-5202-93af-d56bde440b45 (int)
#             int
#           0b5e3059-787a-555f-9bb3-38db93233ab0 (int)
#             int
#           0bd38891-1832-51a7-a311-efd7a4442f77 (int)
#             int
#           0c77c055-2d74-5328-b3b1-eb4f9e1ad63f (int)
#             int
#           0dea6b2e-25bc-5c31-aa1b-a7690af6b853 (int)
#             int
#           1aac00c8-3b6e-5bdd-9fde-6cfcbc7837c0 (int)
#             int
#           1c1fe501-7af9-5df6-9b1e-7187f5445d85 (int)
#             int
#           2137fcba-c774-53da-b051-321a3fcf8f2d (int)
#             int
#           2562f5f1-4de2-5834-a9ff-99092380d910 (int)
#             int
#           26fc6830-a092-5e24-9b58-97f4c38f3e7c (int)
#             int
#           284ed7cc-8917-5005-bfa9-e7c61b1fb85e (int)
#             int
#           2bf3fff9-15c9-5cda-9a04-d0ea22180c77 (int)
#             int
#           2f9c211e-1869-5b3f-94ea-f73b7910a5af (int)
#             int
#           33bdbf35-7ded-53cd-b02c-48d1bb62ed04 (int)
#             int
#           34f1354b-31a3-5ff2-8ee3-70df534c7b1b (int)
#             int
#           36fcaa1e-64e3-56e3-950c-907db167e41f (int)
#             int
#           381e8d26-d8ca-5755-ba19-5fba857a7920 (int)
#             int
#           39adc884-8e24-572d-ad54-74561b1cb139 (int)
#             int
#           39b50224-8305-56dd-9849-09deecb07d20 (int)
#             int
#           39f4ab79-50be-53cd-b422-354d0b320126 (int)
#             int
#           40c181b0-a2d6-54de-ab55-3a09b0b3750b (int)
#             int
#           42022e6f-e123-54a6-84df-ec826b13f5be (int)
#             int
#           4405f887-4eb7-5e3e-874d-1bfe79ec0ada (int)
#             int
#           4492a8f1-a2bf-581a-9ee0-e488f9241c88 (int)
#             int
#           46a7e3a9-4e93-5d73-b35e-6ad63cc195cf (int)
#             int
#           4b135a97-07ad-5cb0-a130-c5900ea1791a (int)
#             int
#           4c9c45db-116c-59e0-a708-d471e38c6361 (int)
#             int
#           4e4cbdec-e2d4-5f31-98a3-f2ef052c849d (int)
#             int
#           51106f17-5dd1-5853-b45b-453d83b9d979 (int)
#             int
#           5119e249-f9be-56b3-9deb-72d7cba52ea8 (int)
#             int
#           53d6532f-43a4-5c01-891c-3ff67a49d290 (int)
#             int
#           55bd38ca-dc73-5c06-8f80-a6ddd2f44382 (int)
#             int
#           564d110e-2a39-5fcb-967a-bacf3a432799 (int)
#             int
#           596a7bd4-895b-5e7c-8124-373fd709444d (int)
#             int
#           5a50a7e8-2ed1-5e8a-8867-c96f1186bd47 (int)
#             int
#           5fab2f5f-3737-5e5b-b572-26abb094331b (int)
#             int
#           62365fbb-af07-5c2a-976d-e3092bdfc317 (int)
#             int
#           66993685-84dd-5143-9454-8a4028d10a6a (int)
#             int
#           67a83049-b3fc-5438-9d37-581ae6f2bcd7 (int)
#             int
#           6b754dda-9a6c-5762-ae67-8069101eb4d4 (int)
#             int
#           6d268c95-c176-5766-9a46-c14f739aba1c (int)
#             int
#           71fd9f58-2931-5c3c-957c-d98f2ab02862 (int)
#             int
#           7248b1c8-b57b-5382-9c5f-4366ed1c254c (int)
#             int
#           73e8c198-4ba4-5f42-9781-167150eae4be (int)
#             int
#           758df5d5-992f-5d30-b6bc-87cb1a0788ab (int)
#             int
#           75e792c1-d5d9-5712-9462-230fa196f861 (int)
#             int
#           75f33095-04ee-5cfc-b58a-863fc8819ba7 (int)
#             int
#           77ce01d6-3609-519e-a0d4-6ad6770c45e4 (int)
#             int
#           799c2ab7-18cb-5be5-92f3-079e27487073 (int)
#             int
#           7b259873-da0b-5e3c-982e-986bf2504820 (int)
#             int
#           8732b0a8-0c4e-5179-9855-d139dbad85c2 (int)
#             int
#           8830d071-858a-534c-ba8f-376dcc56d74e (int)
#             int
#           889c7527-2776-59b2-bebe-9b138ceebaef (int)
#             int
#           8ac972b5-9f6e-5cc8-91c3-b9a40a98232e (int)
#             int
#           8b63019c-7755-502c-b599-b264b0b12c13 (int)
#             int
#           8c2f219b-5122-52b2-940c-988c5818d788 (int)
#             int
#           8d5f87fd-7a87-572b-bdce-303effec6b92 (int)
#             int
#           8e171679-0214-5448-9188-883cfa365c6a (int)
#             int
#           91ea7dc6-6498-5ecf-853f-0090ae00fbfb (int)
#             int
#           9370dddd-ba64-53f9-8890-f391ee305326 (int)
#             int
#           93c6c384-3214-5eee-ab55-c3bbcfae5472 (int)
#             int
#           93ee4f89-0cd1-50a1-9525-401e2fccd32a (int)
#             int
#           94cb0244-f6ae-50c5-ba26-fd3f861c3bb0 (int)
#             int
#           9626b37d-3a04-5cd6-a636-943981354e2b (int)
#             int
#           971aa202-f2c4-5c25-a3d0-15156ed0384c (int)
#             int
#           9acf4d13-d68f-5fec-93b4-caf0a14725a5 (int)
#             int
#           9ba7d620-4e3f-554d-b245-7ad70b63a746 (int)
#             int
#           9bee1901-1125-5635-9e22-3b4f37989c37 (int)
#             int
#           9db6f50d-3242-5cbc-9f71-45477f4967df (int)
#             int
#           a122a3b0-b686-5b96-a02c-926423c65b13 (int)
#             int
#           a29c83ec-1698-5321-b89f-06b782674335 (int)
#             int
#           a2be2e9b-5211-53e6-ac6a-abd65dbcac1d (int)
#             int
#           a3bf2c4d-066f-5397-81c6-a18f25d7e7d8 (int)
#             int
#           a3cc9902-7bc8-577c-8c06-477ef8a82bfb (int)
#             int
#           a840ae9a-5214-52fe-83de-73559845536b (int)
#             int
#           aa1053c3-4b45-5742-beb6-36d9316b204f (int)
#             int
#           ad3f67e9-ab12-5242-a9c8-4a7c3c004934 (int)
#             int
#           b159e707-915c-5940-bd70-7f0416cc8def (int)
#             int
#           b1dd04ef-45b8-5aa8-9564-6cd209a8402f (int)
#             int
#           b49d7ef1-e841-5647-8590-4857eca7e8bd (int)
#             int
#           b91e7385-f4a8-5d1b-ac43-23857284e185 (int)
#             int
#           bc3a62a0-3be0-553f-bf42-a10e954c815f (int)
#             int
#           c0258169-1e97-55b4-8513-427baf8fe898 (int)
#             int
#           c2e79d18-b72d-5219-8418-d0e1f71887c0 (int)
#             int
#           c371ba25-9ad2-5650-af82-98c534ec327a (int)
#             int
#           c63ab08b-7b43-5a3e-bbb8-e69d324b7b1b (int)
#             int
#           c676dcc1-ff7c-51eb-a878-7e1bb3ee6ce2 (int)
#             int
#           c6f3da33-27e8-51e4-9859-ef7cb3cdbe61 (int)
#             int
#           c81dca90-b0cf-5ce8-965c-8dbe5a55cc1b (int)
#             int
#           cb8e5b8f-706a-5b09-884e-ed32ceeec0fd (int)
#             int
#           cdc96814-2f52-5314-80ab-0cff2dcc5054 (int)
#             int
#           cdf65c48-2ac8-522a-bbcf-2f8165187a18 (int)
#             int
#           d15347ac-1e85-5d2a-9979-eef3f15c7376 (int)
#             int
#           d24cf9a8-91e1-55ae-8f2c-023c8a2a14eb (int)
#             int
#           d38298f2-29e8-57b0-b978-140aa2171cce (int)
#             int
#           d68306e2-9877-5987-84b3-12b8234c8eec (int)
#             int
#           d833c453-58c5-5ff6-91b2-f526ca5f808a (int)
#             int
#           da226026-1ef7-5663-bc44-a1218f8a0b7d (int)
#             int
#           db398a18-0d81-50ba-bc86-a7de52a1be7f (int)
#             int
#           e24e5e4e-722f-56ff-9555-9b76303fc6be (int)
#             int
#           e43188e9-33c7-5df9-b611-c2d2ddd3d78f (int)
#             int
#           e732ba9a-fdfa-50a3-80a4-d91af06d575e (int)
#             int
#           e737e5cd-43e1-5a29-a977-fbb673c6367c (int)
#             int
#           e9cf9c31-aa62-53f4-bff2-71cd5e2f4004 (int)
#             int
#           eb5c94c7-5494-5669-9c54-6f3672d65683 (int)
#             int
#           f1eba89f-dd82-5843-80a9-e9b2cd3a6037 (int)
#             int
#           f37b2caa-03c5-51ec-a02a-c2e5311a9fd5 (int)
#             int
#           f4937944-9439-5887-85e0-fc3705243da8 (int)
#             int
#           f4cf6831-f6af-51c9-af91-1246830ae0fd (int)
#             int
#           f4cf6ecc-c308-5d3f-8358-ab273f375a68 (int)
#             int
#           f58e52e4-ab1c-5ccf-a751-5d174e5138a2 (int)
#             int
#           f7aa8817-24f8-5dbb-a726-353611565ffe (int)
#             int
#           f9be8a22-a0cb-54e3-adbd-97fc4a5a3b8e (int)
#             int
#           fadda48c-6226-5ac5-a2b9-e9170d2017cd (int)
#             int
#           fdbec3b3-f6f2-5149-a70a-4f9d2622a87b (int)
#             int
#           fdfd9504-cf9b-5fec-81ba-fd23f2e509d6 (int)
#             int
#           fea2ad06-355d-5a9a-822d-66275d89cad9 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       foilBasic (dict, len=3)
#         cards (dict, len=20)
#           053c8559-8ab8-5a1a-9444-6140b41470c4 (int)
#             int
#           06ac124d-5c6e-542e-bf11-552ec9cc19cc (int)
#             int
#           0f0aa930-854b-59fb-bd76-69d987356f90 (int)
#             int
#           2e21d91d-3970-503f-b36a-e2b0e37fb3ee (int)
#             int
#           31bd4e75-e2c5-5252-a7ff-4eb2a99a4a44 (int)
#             int
#           3d407269-4586-51e3-9da6-298d65aff831 (int)
#             int
#           3e12f3ab-96ab-5d5a-8bed-92b37ffee9aa (int)
#             int
#           3e951ede-39fc-58c6-8a89-e2c320902ddd (int)
#             int
#           47e1bdab-e112-526d-bd9f-7f1cffef7187 (int)
#             int
#           4a17c998-1a44-5537-b675-b19522d43bee (int)
#             int
#           4b3673bc-4f31-5877-9710-44d875dcca8a (int)
#             int
#           4d710f8c-6249-5877-9799-edf65d0c3e68 (int)
#             int
#           6c88ef33-31c8-545f-96dc-de46d68bdbc9 (int)
#             int
#           77977762-e1e1-507b-8d59-e9ed6671a926 (int)
#             int
#           87d6bcfb-0e75-59f7-be6c-30aa7c344ccb (int)
#             int
#           a494d14e-b4c3-5467-8af5-bad8b41da09a (int)
#             int
#           c1f98960-ef31-5ec9-af8d-d6d56169047b (int)
#             int
#           c4823642-08dd-5c10-ae26-ef8d52cf3a43 (int)
#             int
#           ec72e59f-bc37-50fd-a1b5-3afac5a402b3 (int)
#             int
#           eedae11d-cb7c-5b59-bcdd-419e3d6311a1 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       foilCommon (dict, len=3)
#         cards (dict, len=121)
#           004adf9a-b59a-5d56-9093-df73b9929bb1 (int)
#             int
#           01248698-729b-5a69-ba8c-f1686a181abb (int)
#             int
#           02e23fa1-b2f0-528c-b331-12a0c27bc5eb (int)
#             int
#           08099cff-a271-54f1-942e-2fe7101c7bac (int)
#             int
#           08548840-8e62-5fed-b432-f2a5a0cb5f4e (int)
#             int
#           0b5e3059-787a-555f-9bb3-38db93233ab0 (int)
#             int
#           0bd38891-1832-51a7-a311-efd7a4442f77 (int)
#             int
#           0d2a4e1d-cc12-5675-8044-9a7bc7d60050 (int)
#             int
#           0dea6b2e-25bc-5c31-aa1b-a7690af6b853 (int)
#             int
#           1aac00c8-3b6e-5bdd-9fde-6cfcbc7837c0 (int)
#             int
#           1b122375-8e96-5a83-969a-2d772eceba4d (int)
#             int
#           2137fcba-c774-53da-b051-321a3fcf8f2d (int)
#             int
#           23aabc91-9146-5367-9cce-4fe955861abb (int)
#             int
#           265e33a7-c32f-5177-8b16-8998931bc8a4 (int)
#             int
#           27d4596d-3c6c-5d6e-a978-424044a468d4 (int)
#             int
#           284ed7cc-8917-5005-bfa9-e7c61b1fb85e (int)
#             int
#           285ed705-6771-5dc8-8076-c252fe984278 (int)
#             int
#           2bbaf3d6-9fbc-5ab8-93d3-d26e2ddec999 (int)
#             int
#           2bf3fff9-15c9-5cda-9a04-d0ea22180c77 (int)
#             int
#           2f9c211e-1869-5b3f-94ea-f73b7910a5af (int)
#             int
#           307db1e5-c643-578c-9e1d-718dd92694d7 (int)
#             int
#           33bdbf35-7ded-53cd-b02c-48d1bb62ed04 (int)
#             int
#           39adc884-8e24-572d-ad54-74561b1cb139 (int)
#             int
#           39b50224-8305-56dd-9849-09deecb07d20 (int)
#             int
#           39f4ab79-50be-53cd-b422-354d0b320126 (int)
#             int
#           40c181b0-a2d6-54de-ab55-3a09b0b3750b (int)
#             int
#           41b6098d-f7d9-5a37-9734-01dff7ce4912 (int)
#             int
#           4405f887-4eb7-5e3e-874d-1bfe79ec0ada (int)
#             int
#           4492a8f1-a2bf-581a-9ee0-e488f9241c88 (int)
#             int
#           46a7e3a9-4e93-5d73-b35e-6ad63cc195cf (int)
#             int
#           4b135a97-07ad-5cb0-a130-c5900ea1791a (int)
#             int
#           4c708bbf-9168-5fa5-a02e-5ce3bcc6158b (int)
#             int
#           4e83393d-bb3f-5e39-8730-45202587ad47 (int)
#             int
#           4fed8c53-5ff9-51ce-a7a8-2fc629bf3d24 (int)
#             int
#           51106f17-5dd1-5853-b45b-453d83b9d979 (int)
#             int
#           5cfbcc15-d710-51d0-b0e8-90e66649839e (int)
#             int
#           5e670818-f7b1-52a6-bc6f-c9eccb8ce3ef (int)
#             int
#           5fab2f5f-3737-5e5b-b572-26abb094331b (int)
#             int
#           60b93108-8790-591b-844e-c3d311698767 (int)
#             int
#           61a544c2-1700-500c-b93f-bc292114df3f (int)
#             int
#           65b16f51-24dc-5039-9d54-4a00c387fc82 (int)
#             int
#           67a83049-b3fc-5438-9d37-581ae6f2bcd7 (int)
#             int
#           67adcf6f-bf56-5ca8-a3fb-a1045b4fba41 (int)
#             int
#           68c5cace-080c-55d1-a55a-6c2190479941 (int)
#             int
#           6adaf14d-43e3-521a-adf1-960c808e5b1a (int)
#             int
#           6d268c95-c176-5766-9a46-c14f739aba1c (int)
#             int
#           71fd9f58-2931-5c3c-957c-d98f2ab02862 (int)
#             int
#           7248b1c8-b57b-5382-9c5f-4366ed1c254c (int)
#             int
#           73e8c198-4ba4-5f42-9781-167150eae4be (int)
#             int
#           77ce01d6-3609-519e-a0d4-6ad6770c45e4 (int)
#             int
#           79996e77-112f-51e8-980c-0ec82f2d7754 (int)
#             int
#           799c2ab7-18cb-5be5-92f3-079e27487073 (int)
#             int
#           7b259873-da0b-5e3c-982e-986bf2504820 (int)
#             int
#           8732b0a8-0c4e-5179-9855-d139dbad85c2 (int)
#             int
#           8830d071-858a-534c-ba8f-376dcc56d74e (int)
#             int
#           889c7527-2776-59b2-bebe-9b138ceebaef (int)
#             int
#           8b63019c-7755-502c-b599-b264b0b12c13 (int)
#             int
#           8c2f219b-5122-52b2-940c-988c5818d788 (int)
#             int
#           8d5f87fd-7a87-572b-bdce-303effec6b92 (int)
#             int
#           8e171679-0214-5448-9188-883cfa365c6a (int)
#             int
#           90b87b65-7385-596e-bbea-64fe7dd67ed4 (int)
#             int
#           91ea7dc6-6498-5ecf-853f-0090ae00fbfb (int)
#             int
#           9370dddd-ba64-53f9-8890-f391ee305326 (int)
#             int
#           93c6c384-3214-5eee-ab55-c3bbcfae5472 (int)
#             int
#           93ee4f89-0cd1-50a1-9525-401e2fccd32a (int)
#             int
#           971aa202-f2c4-5c25-a3d0-15156ed0384c (int)
#             int
#           9acf4d13-d68f-5fec-93b4-caf0a14725a5 (int)
#             int
#           9ba7d620-4e3f-554d-b245-7ad70b63a746 (int)
#             int
#           9bee1901-1125-5635-9e22-3b4f37989c37 (int)
#             int
#           9c0311e8-03c1-527d-9d90-6fa2dba2aae9 (int)
#             int
#           9db6f50d-3242-5cbc-9f71-45477f4967df (int)
#             int
#           9e583bce-5201-59f8-aa5c-f85c55824f41 (int)
#             int
#           a2be2e9b-5211-53e6-ac6a-abd65dbcac1d (int)
#             int
#           a3bf2c4d-066f-5397-81c6-a18f25d7e7d8 (int)
#             int
#           a3cc9902-7bc8-577c-8c06-477ef8a82bfb (int)
#             int
#           a6778999-a426-51ea-82d1-749bf98619be (int)
#             int
#           aa1053c3-4b45-5742-beb6-36d9316b204f (int)
#             int
#           ad3f67e9-ab12-5242-a9c8-4a7c3c004934 (int)
#             int
#           b1dd04ef-45b8-5aa8-9564-6cd209a8402f (int)
#             int
#           b1e43df0-d501-5297-9cb4-c84d2a76945d (int)
#             int
#           b49d7ef1-e841-5647-8590-4857eca7e8bd (int)
#             int
#           b75509f6-c893-54a7-a51e-757066a0b4da (int)
#             int
#           ba5acf09-98cc-5052-b65e-c5145e92fc1a (int)
#             int
#           bf599cd8-8095-5725-bcca-244b9e69f5d0 (int)
#             int
#           bfed2fdd-d029-545f-88f7-5ab45446cf27 (int)
#             int
#           c0258169-1e97-55b4-8513-427baf8fe898 (int)
#             int
#           c0b0e7a5-4252-57f5-8ed0-399d08c0523f (int)
#             int
#           c3b8083a-bbe4-524f-8e90-8b8a493152db (int)
#             int
#           c5655330-5131-5f40-9d3e-0549d88c6e9e (int)
#             int
#           c63ab08b-7b43-5a3e-bbb8-e69d324b7b1b (int)
#             int
#           c676dcc1-ff7c-51eb-a878-7e1bb3ee6ce2 (int)
#             int
#           c6f3da33-27e8-51e4-9859-ef7cb3cdbe61 (int)
#             int
#           cb8e5b8f-706a-5b09-884e-ed32ceeec0fd (int)
#             int
#           cdc96814-2f52-5314-80ab-0cff2dcc5054 (int)
#             int
#           d15347ac-1e85-5d2a-9979-eef3f15c7376 (int)
#             int
#           d24cf9a8-91e1-55ae-8f2c-023c8a2a14eb (int)
#             int
#           d38298f2-29e8-57b0-b978-140aa2171cce (int)
#             int
#           d68306e2-9877-5987-84b3-12b8234c8eec (int)
#             int
#           da226026-1ef7-5663-bc44-a1218f8a0b7d (int)
#             int
#           db62961f-51de-569a-bfd8-b3f82abf1b18 (int)
#             int
#           e11ae348-44d1-5d45-bc5c-99a44d2acd5c (int)
#             int
#           e24e5e4e-722f-56ff-9555-9b76303fc6be (int)
#             int
#           e43188e9-33c7-5df9-b611-c2d2ddd3d78f (int)
#             int
#           e4b4684b-8e14-5fcf-9286-497b7afd5b3a (int)
#             int
#           e65aae37-20bc-5499-aee4-c1f30832f7b0 (int)
#             int
#           e732ba9a-fdfa-50a3-80a4-d91af06d575e (int)
#             int
#           e9397b67-e88c-5f8b-9839-b8887bb9c1bf (int)
#             int
#           eb5c94c7-5494-5669-9c54-6f3672d65683 (int)
#             int
#           edc4b78a-6130-5fd4-b5ff-c46850e2b957 (int)
#             int
#           ede09d78-f4b5-59eb-8356-dd125323f74f (int)
#             int
#           f286fe97-e2ad-5a5a-8e7f-0caa9dc898b4 (int)
#             int
#           f37b2caa-03c5-51ec-a02a-c2e5311a9fd5 (int)
#             int
#           f49300ef-efa0-5b82-ace3-f2f06795fbd5 (int)
#             int
#           f4cf6831-f6af-51c9-af91-1246830ae0fd (int)
#             int
#           f58e52e4-ab1c-5ccf-a751-5d174e5138a2 (int)
#             int
#           f76ee94d-b1a1-5c9f-bdc8-4bf659844cd8 (int)
#             int
#           f7aa8817-24f8-5dbb-a726-353611565ffe (int)
#             int
#           f82185b9-c5c6-50f3-a681-0241e7d52503 (int)
#             int
#           f9be8a22-a0cb-54e3-adbd-97fc4a5a3b8e (int)
#             int
#           fdfd9504-cf9b-5fec-81ba-fd23f2e509d6 (int)
#             int
#           fea2ad06-355d-5a9a-822d-66275d89cad9 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       foilRare (dict, len=3)
#         cards (dict, len=121)
#           03b06cf7-aa45-504c-b4af-ceefce384f25 (int)
#             int
#           0720c621-c070-5870-b4d7-40d2cae2cb5f (int)
#             int
#           08a671f0-ea90-531e-bbeb-c00793a57672 (int)
#             int
#           0a8f1091-c245-5569-b121-ffd0a50008b5 (int)
#             int
#           0af7633e-8851-5afa-8611-fb3272f05fef (int)
#             int
#           0bcc33de-dce2-556f-9bdc-080f7ae67529 (int)
#             int
#           0cc99e92-fbb3-52d1-909c-ee619996e795 (int)
#             int
#           0d3888b4-3eb2-5cb5-b7de-0c8a3257f0cc (int)
#             int
#           0ead5084-cdde-5f7e-a60b-1a0b9f64a995 (int)
#             int
#           100f46ae-e457-5491-b5d1-66cd9284304c (int)
#             int
#           1102852c-8ade-5273-b9a3-4acb8ad97060 (int)
#             int
#           11727081-4070-56db-8162-b970dd7f94bc (int)
#             int
#           12458b60-30cf-5ce8-aa7d-89c8a75575e6 (int)
#             int
#           1430ebef-2e40-57ce-8801-2f94b05d027e (int)
#             int
#           15139516-eb75-5f45-b35f-3372217cfc95 (int)
#             int
#           1afcbee1-1310-5144-86ea-e7bf0fb34d2b (int)
#             int
#           204da544-dd71-552f-9bbd-bdb2cfa01964 (int)
#             int
#           206c4a07-1442-5fee-acd8-7a8a00da57a4 (int)
#             int
#           22578321-9dba-5729-ade5-69c7b61f77fa (int)
#             int
#           23d4bb2e-1ed1-5f22-8b08-bbdc15dcb31e (int)
#             int
#           23e48622-2895-5385-99a4-892c93a5d3d2 (int)
#             int
#           2443b453-cb6e-5981-b7ff-3bb6ecb06c3e (int)
#             int
#           274c6a91-31d3-5adb-8707-3edca2cb62b6 (int)
#             int
#           29723d8d-34c9-5009-8b79-2c679e35f674 (int)
#             int
#           2c6cd5b8-2f45-5ce2-9e60-6b381d8c88c9 (int)
#             int
#           2f39f144-a02a-5017-a45a-4a3cfc2c7a36 (int)
#             int
#           341f9c8d-a838-58f9-933b-094c8d889a88 (int)
#             int
#           3616d597-cbda-5839-9478-85b8e18d0011 (int)
#             int
#           373a5b22-c165-5533-aa12-893f13cc06d2 (int)
#             int
#           38513fa0-ea83-5642-8ecd-4f0b3daa6768 (int)
#             int
#           39afdeca-0f97-5d0a-ac7f-af0ae4d75b76 (int)
#             int
#           3b77bb52-4181-57f5-b3cd-f3a15b95aa29 (int)
#             int
#           3c0d065a-4aa4-55f4-bc11-bd326d23e5a6 (int)
#             int
#           3c25757c-4c47-5685-a14d-dcabb08fc79b (int)
#             int
#           3c6b79b0-1a84-5584-83c6-954430868f62 (int)
#             int
#           3e72aae2-58f2-5c9f-9450-cbbb7e2c0111 (int)
#             int
#           3f736237-5bba-5b24-8fc5-ad279eec8c1b (int)
#             int
#           3f809288-0eaa-5f55-8144-483ed8ea810c (int)
#             int
#           410efb52-131f-5288-8bc5-a9c4a1e7bef9 (int)
#             int
#           47432616-5812-59fd-b90e-88dadd613161 (int)
#             int
#           47fe8296-36c6-5338-b239-9fa0cceba156 (int)
#             int
#           49383392-e722-56a9-afd0-c531ecb05310 (int)
#             int
#           49f64f3e-f0ff-5d4c-a730-5ea919857d82 (int)
#             int
#           4afd939d-f7b3-5807-bcc9-c2d7d4ac3ff9 (int)
#             int
#           4b375581-c43d-5bd1-b990-a0fa496b8262 (int)
#             int
#           4cd3a77f-82ac-5204-8f60-b04234d2db30 (int)
#             int
#           546eac7c-1424-597d-ac13-bf8558e88fe3 (int)
#             int
#           5543c576-ef2b-59ac-878b-3aff199f27de (int)
#             int
#           56abb591-a158-5945-8dd6-97664f1c82cc (int)
#             int
#           56f4935b-f6c5-59b9-88bf-9bcce20247ce (int)
#             int
#           5a1f3fc3-e970-5408-94ef-e7c78e57000b (int)
#             int
#           5ac794d2-4c66-5332-afb1-54b24bc11823 (int)
#             int
#           5c0bbc6b-9f29-5d67-9065-22a1d99ad7e5 (int)
#             int
#           5e52c0be-d4fa-5f73-8d06-1080da4d0942 (int)
#             int
#           5ef80896-673a-548a-9eaa-05db2cbb07a0 (int)
#             int
#           5ff7b860-8e0f-51a3-a2db-9819417afd06 (int)
#             int
#           6022d604-c21f-599e-b65e-ff895bc51005 (int)
#             int
#           6b7fba1d-4937-5867-8a77-863ec30d432e (int)
#             int
#           6bb35d3c-20f6-5e0e-aea9-cffbef432373 (int)
#             int
#           6d6a31d5-a80b-5f31-9b46-2c2083a95581 (int)
#             int
#           6f08f7f6-ecfb-584f-ae7a-c6e4d9c4da35 (int)
#             int
#           6f9ae90a-5638-5b88-a3d7-ccea4372eb79 (int)
#             int
#           725ab389-a7a2-5869-929b-c8e1098b547d (int)
#             int
#           7887f1e9-6c2f-5d54-bf8d-8ebbb956fd6b (int)
#             int
#           7e457744-dd60-5fd0-ae58-1718ef65c1a1 (int)
#             int
#           80baae17-693b-5662-aad7-071f3b031fad (int)
#             int
#           81daea6a-2735-5a46-a2da-b65a2ad5738f (int)
#             int
#           82306a22-03b6-5cbd-ba72-0002755c4217 (int)
#             int
#           85245362-de1a-59fd-9f9a-d6a0c9522592 (int)
#             int
#           86b465df-0605-555c-aaa4-303f7e32d4d2 (int)
#             int
#           8b56bd26-7d38-50f1-b4ce-5b6989081b83 (int)
#             int
#           8dfc67e9-8323-5d1f-9e25-9f9394abd5a0 (int)
#             int
#           8ea7f1a9-a15e-5775-af3e-1a56a1e0b098 (int)
#             int
#           952369f6-d553-558f-8385-5c219c66653b (int)
#             int
#           98becc43-123e-5e33-90f0-59318c221f4b (int)
#             int
#           9932f234-b27f-55df-96be-18b6583ba3df (int)
#             int
#           99be8d57-8eeb-5208-aa32-0a303e000795 (int)
#             int
#           9a14261a-b567-5429-a5ca-a913e15d8bf7 (int)
#             int
#           9a6b8e1e-1dc7-5807-bafd-bcd4fa1c6401 (int)
#             int
#           9ae3a282-1852-5b73-8c60-eabca0956349 (int)
#             int
#           9af574e4-dc6e-5246-8fe7-fee6c4c77a76 (int)
#             int
#           9e49c166-9728-5259-b3e9-758b3c1357c6 (int)
#             int
#           9f315280-5d52-5dea-a679-a2d97386907e (int)
#             int
#           a139944e-bae3-523b-a29c-4aa3c544e532 (int)
#             int
#           a5e37da8-d36c-5bcb-945d-7be448ddc7ba (int)
#             int
#           a807430a-5a37-550c-989f-72d125d7b0c8 (int)
#             int
#           aa1c3b14-8a65-55ba-b741-68eef451a922 (int)
#             int
#           ac19e0e0-6d8e-55ad-a7a9-68fd6032eaab (int)
#             int
#           ad67ee3e-ce9d-5fd4-845b-a1673f717f8b (int)
#             int
#           afdc12d3-7a55-5b55-b85c-12195718c79a (int)
#             int
#           b00ad339-0cc1-59d4-b8a4-c827b6512b6c (int)
#             int
#           b0a0f3ea-f483-53e3-ae41-bdb409141fdf (int)
#             int
#           b2f56602-e85a-588f-a4be-40b6e56f44f7 (int)
#             int
#           b5bdfa8c-00ab-5b6a-b97a-ee77ffcbc4e9 (int)
#             int
#           ba1b342b-9a40-5bdb-9a64-e392b752bd76 (int)
#             int
#           bb6e511d-3e7f-5dd3-b40c-dbeb09c734f7 (int)
#             int
#           c206ab94-4325-5766-91d6-62b8f50aeac8 (int)
#             int
#           c3808d11-6614-57a9-b4bf-d276aa88f5a8 (int)
#             int
#           c6eedc08-9b48-52b9-a9ec-bb0347fd3987 (int)
#             int
#           c84cfe08-d681-58e9-a003-1447f3b6d0f7 (int)
#             int
#           c879e36f-630c-573d-a6a6-25737805752f (int)
#             int
#           ca560ce6-8093-51e9-9b7f-2c11756d6516 (int)
#             int
#           cae5ac32-6265-5615-a060-21fb1a2dea5a (int)
#             int
#           cb833dcb-2d9b-528d-bf47-889102212f44 (int)
#             int
#           ceb02498-5932-532d-80f3-0f2d892aaed6 (int)
#             int
#           d1797b46-68c8-57b9-913e-cca4feb3dae8 (int)
#             int
#           d44d44ca-fa5a-59e7-8790-f9b107f6c2f7 (int)
#             int
#           d6fff2c5-c356-543e-9708-3a25de95244a (int)
#             int
#           d899942a-ee50-5305-ab9c-5000f9bb3708 (int)
#             int
#           da8f1e81-fc1f-57f4-b4ec-0c5445a299e8 (int)
#             int
#           dec9c4f1-455e-56de-aad4-9a1d18cf5588 (int)
#             int
#           e5b81af3-5518-57ab-b42b-ab62e3732c72 (int)
#             int
#           e8650f78-41cc-562b-b18a-b20207d716e5 (int)
#             int
#           efdd5367-9393-54c1-a6b8-c7810ee87ed5 (int)
#             int
#           f180c680-0dc9-5132-a713-65fdc4eefa75 (int)
#             int
#           f39b4446-0ca6-5446-8507-4b1ba37bb3e7 (int)
#             int
#           f4670242-6ae0-5ec4-872d-391386bb026b (int)
#             int
#           f4ee3e9e-21da-5a63-8278-3efa59da7df3 (int)
#             int
#           fc96da15-9362-585a-b555-f7a7e5480e8b (int)
#             int
#           ff703e3a-4ea3-59d6-99e5-02c4db74f035 (int)
#             int
#           ffe80735-543f-53c2-9e48-ee66c78d7393 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       foilUncommon (dict, len=3)
#         cards (dict, len=121)
#           01d6c876-b6e6-5534-8bef-42862a9cd839 (int)
#             int
#           01e48603-fbf2-5178-92d2-3d6c9944f4b5 (int)
#             int
#           022ee2d2-d02b-580e-a549-ed9555ef9153 (int)
#             int
#           06058b88-09c6-5475-a4b3-a72df2a7bea0 (int)
#             int
#           062e0ec2-391d-5394-a5d6-04dbc467751f (int)
#             int
#           06af24c4-9cbe-5c8f-9c22-63273cf74ce6 (int)
#             int
#           0bd58de8-5807-55d0-a5ad-ebe42f2f1ebc (int)
#             int
#           0c960d75-fd2e-5a5a-ba78-58e10530fea0 (int)
#             int
#           0d2b2057-eb16-5435-aea9-61b3038ae9b2 (int)
#             int
#           0da4a2a0-4d13-5c8a-bdff-12b67070798e (int)
#             int
#           14878086-100b-5658-a753-571278cbb546 (int)
#             int
#           16342dc0-7314-5c08-a076-eeeb1956b7f3 (int)
#             int
#           16b6100b-950e-567e-a815-603b78f526e0 (int)
#             int
#           1ebad7f2-d761-56b8-81ae-1e0225968026 (int)
#             int
#           2081f76c-b206-5d08-a191-fcb60723b9fa (int)
#             int
#           222c5769-1eff-5539-a79e-33d1db864d6c (int)
#             int
#           26180f1b-41a1-5fa5-9f6b-39ee08a1a203 (int)
#             int
#           27745694-8868-5240-aa72-cdb326bd1e90 (int)
#             int
#           312306e1-001c-50b8-9a24-249bd40cfae3 (int)
#             int
#           31ecdb2e-eec0-56fb-9a12-7af9069f3673 (int)
#             int
#           3785490a-01f5-511d-b471-60b1209b3d4f (int)
#             int
#           37f0071d-09b9-5fdc-a5de-52061a01cb64 (int)
#             int
#           3a76f884-3f71-5dbd-8ac8-6bb24e72704d (int)
#             int
#           4429ce97-b78e-5bc4-bd34-a38b26794bdf (int)
#             int
#           4b7ee21b-ccb2-5590-98d7-146bbe0ba10c (int)
#             int
#           4bdb6002-18d3-5a09-a94c-da7796980b83 (int)
#             int
#           4c1a672a-3089-563f-a852-9580a425dbf1 (int)
#             int
#           4c9c5ea9-5bca-5301-a0a2-2680fe75b04a (int)
#             int
#           4dd68de9-3c96-5c4f-b829-3c5c2c485c55 (int)
#             int
#           4ed247e0-386b-5166-9c99-875d6f82f681 (int)
#             int
#           4fa9bf42-9170-594e-bbf9-42111adea313 (int)
#             int
#           4ffc3780-0054-5128-b97e-b19d06b483c6 (int)
#             int
#           518754bb-441f-5f22-a106-377017a55ccc (int)
#             int
#           52d9f396-b080-5da2-b904-302c6f319f94 (int)
#             int
#           55492210-8ce6-553c-bdb7-573d824ca3c3 (int)
#             int
#           5b975ab5-c9d5-5fd3-a425-27842542683a (int)
#             int
#           60122d6f-448b-5df8-ac2a-8f5a1e841278 (int)
#             int
#           60d613d8-fd21-5d63-b920-75c0d3e12121 (int)
#             int
#           60f49caf-3583-5f85-b4b3-08dca73a8628 (int)
#             int
#           613639f1-7372-5b5c-9109-bef041108023 (int)
#             int
#           65e0dbca-81ed-538d-8f71-d5ddc5a927b9 (int)
#             int
#           66cdbfaf-8bc2-5313-9c5c-7d422d2e4b0a (int)
#             int
#           6c4d1103-3acd-5828-9bf7-77a0b1d405a4 (int)
#             int
#           6c515488-2a63-5b1e-84a4-987b5fa993af (int)
#             int
#           6d030b32-0534-55c9-9c40-00bb59d4e164 (int)
#             int
#           6e2980cb-0c4a-521b-a99f-072533de225e (int)
#             int
#           7069fe50-d855-59ea-b445-e8068cda7559 (int)
#             int
#           70eb81fd-23fb-521a-9ac3-fae8f0ca5bf0 (int)
#             int
#           75578928-5ef3-5c91-87d8-e16191a1764e (int)
#             int
#           767ee0a4-a8fa-5bce-a948-0a067fa4ba89 (int)
#             int
#           76d4f437-02e5-5f1c-a1d3-eddb55e8725d (int)
#             int
#           7bd0f6ac-3239-57c5-89a1-f2edc86a4be7 (int)
#             int
#           7db42d14-4950-5478-b87c-fbbd93889801 (int)
#             int
#           7fef665c-36a1-5f7a-9299-cf8938708710 (int)
#             int
#           8402d391-a810-5c04-af77-d3fb01dbacca (int)
#             int
#           855f7c1e-d582-5ae3-8f58-00a5c0d77c03 (int)
#             int
#           85e3e30b-c47d-5606-a6fd-0b4a9931de79 (int)
#             int
#           8b39d0fc-ddef-5d5a-95fc-975bee2fbe06 (int)
#             int
#           8d4f5d80-16ea-52cc-8201-93a46b803efb (int)
#             int
#           8d5006e3-45cb-5d9f-896d-83a22d86d53d (int)
#             int
#           8d805d91-280e-5c7e-81d2-2676b9ee93b5 (int)
#             int
#           8dfa8b47-af66-51df-9472-16c2bc4cf8f5 (int)
#             int
#           8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a (int)
#             int
#           93043613-bd0a-5937-a129-3c089a63ca8a (int)
#             int
#           976585bc-fe72-56aa-b841-c4331d81655f (int)
#             int
#           9add78c6-3207-5f67-aa15-618adb14497b (int)
#             int
#           9e0f4c70-6db0-5798-8307-caf4f98f17f9 (int)
#             int
#           9f55a614-586a-53dd-881a-d4a9648f2ba8 (int)
#             int
#           a1629073-cd64-5aa4-aca6-4d4e64dff8e2 (int)
#             int
#           a4bd6d9a-942d-53a3-8607-2354f86cc810 (int)
#             int
#           a69b404f-144a-5317-b10e-7d9dce135b24 (int)
#             int
#           a778b5ec-ca7e-5e11-92e0-c1a99b8599cd (int)
#             int
#           a9a74d88-7663-5419-a74c-5a28e8642b4f (int)
#             int
#           ab4f32a2-6671-5724-8ce9-6b721a5f2417 (int)
#             int
#           abb362ed-d21a-5b20-929a-9caca69b3dc8 (int)
#             int
#           ae68e914-6896-5ee8-af5f-8ea88f5e0200 (int)
#             int
#           aeb1b742-645c-5dab-ba9b-35d51649e074 (int)
#             int
#           b240df99-f98a-5450-a3e2-cc0946bb1caa (int)
#             int
#           b3de8302-e27e-5553-9ed6-f6a6f5fad14d (int)
#             int
#           b6b8b11d-0406-54e5-aed1-46d1588262e2 (int)
#             int
#           b7c19924-b4bf-56fc-aa73-f586e940bd42 (int)
#             int
#           b8a68840-4044-52c0-a14e-0a1c630ba42c (int)
#             int
#           bbea1480-68f2-51fb-8ac9-e7c7485f39fc (int)
#             int
#           bc899285-8adc-5280-92fd-dcf278c76da3 (int)
#             int
#           bcc70712-566e-5a6f-8d73-f1ab87c57454 (int)
#             int
#           c19bcfc2-fc10-5040-8239-1c193098df47 (int)
#             int
#           c31c9d06-507b-59fa-a1bc-402d38a5d9a8 (int)
#             int
#           c397d44d-ce30-511a-af0a-3c6a7f977df1 (int)
#             int
#           c7e4eda9-dc2e-5243-8a1d-7097e3b2b319 (int)
#             int
#           c7f34f83-c800-5987-8520-5ae1705871d9 (int)
#             int
#           cb865391-5b14-58ce-aa99-b36b83e6377f (int)
#             int
#           cdc0805a-73b1-5d98-bff3-4e06e6a1f036 (int)
#             int
#           cfa41bcc-edea-53e6-8aec-e7f9d5d23089 (int)
#             int
#           d089fdc1-4d21-58e8-b9c8-23d8b3191fe5 (int)
#             int
#           d1b05ebd-7023-5236-bf3b-470476c6f59a (int)
#             int
#           d44c9385-588c-50e2-a3fc-2ff233f41086 (int)
#             int
#           d9902515-6292-5a4a-9bde-a7616ad5f0bc (int)
#             int
#           da0a5791-2fc2-53e4-bc8b-c4d8cd026ded (int)
#             int
#           dc219ada-64b4-5846-9840-e49986109aa9 (int)
#             int
#           de602e4a-da36-5b49-a2ed-388bcdbfb54f (int)
#             int
#           e2066f75-65de-5254-82f2-8e1f969bf31b (int)
#             int
#           e35dd1c6-3d00-5d23-898f-aa07be8e98aa (int)
#             int
#           e451cc8a-2bbe-5850-adc4-fb1b738bcef0 (int)
#             int
#           e54f8939-0853-5b0b-81b0-a29391bfb9e0 (int)
#             int
#           e553a0fb-cc04-551c-b0f7-f047cf0c2d0c (int)
#             int
#           e691cb00-dabd-51ec-a678-6227dddb7b80 (int)
#             int
#           e77dbe8c-5878-5881-b5f3-8203af673278 (int)
#             int
#           e9435188-40bd-54c7-938f-798459b038ed (int)
#             int
#           ec5227b0-8cbd-5cad-a27e-32a798a3ae0a (int)
#             int
#           ecf2b08e-7eca-5f13-a9f7-7a915ee259f5 (int)
#             int
#           eee00aa2-c730-5ff1-84a9-51d95a9fe180 (int)
#             int
#           eef8487a-450f-5e19-b9f1-2886839d02ec (int)
#             int
#           efaa7c3d-c5e0-5346-b3b2-c6a3d132c27a (int)
#             int
#           efe6103c-6a3e-5ed0-a689-81a2efe4273b (int)
#             int
#           f44e0c48-1740-5e18-859f-4e4615f3a3b1 (int)
#             int
#           f8084160-8edf-58fa-b453-81daf28278d0 (int)
#             int
#           f83c4766-5cf2-5ccb-943c-3c938b78c7b4 (int)
#             int
#           f90fe5cb-ee47-51f2-8a8c-3ced26f1b446 (int)
#             int
#           f92a05a7-c0b3-5136-92c2-a8b6b6531bf3 (int)
#             int
#           fac6ad26-f8c2-51bd-9f6a-a1b0940b4cef (int)
#             int
#           fd50dffd-b4d8-5956-9fec-b454fd1fef06 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       rare (dict, len=3)
#         cards (dict, len=121)
#           03b06cf7-aa45-504c-b4af-ceefce384f25 (int)
#             int
#           0af7633e-8851-5afa-8611-fb3272f05fef (int)
#             int
#           0bcc33de-dce2-556f-9bdc-080f7ae67529 (int)
#             int
#           0cc99e92-fbb3-52d1-909c-ee619996e795 (int)
#             int
#           0d3888b4-3eb2-5cb5-b7de-0c8a3257f0cc (int)
#             int
#           0ead5084-cdde-5f7e-a60b-1a0b9f64a995 (int)
#             int
#           100f46ae-e457-5491-b5d1-66cd9284304c (int)
#             int
#           11727081-4070-56db-8162-b970dd7f94bc (int)
#             int
#           1430ebef-2e40-57ce-8801-2f94b05d027e (int)
#             int
#           15139516-eb75-5f45-b35f-3372217cfc95 (int)
#             int
#           154824ca-2444-5562-927f-cedddab5a8aa (int)
#             int
#           1cc6e0b9-e297-5ea0-9e51-d6fbd4fe512c (int)
#             int
#           204da544-dd71-552f-9bbd-bdb2cfa01964 (int)
#             int
#           214dbfe9-0f16-5b6b-be30-8771192a89ec (int)
#             int
#           21edc41a-e830-58d0-80b5-85eabe32d0d7 (int)
#             int
#           23d4bb2e-1ed1-5f22-8b08-bbdc15dcb31e (int)
#             int
#           23e48622-2895-5385-99a4-892c93a5d3d2 (int)
#             int
#           2443b453-cb6e-5981-b7ff-3bb6ecb06c3e (int)
#             int
#           25634111-8644-5d96-9e23-3b00c2ea0ed5 (int)
#             int
#           274c6a91-31d3-5adb-8707-3edca2cb62b6 (int)
#             int
#           28e56ac7-6a09-5118-9ade-6755b051bc0b (int)
#             int
#           29723d8d-34c9-5009-8b79-2c679e35f674 (int)
#             int
#           2b887770-1bb2-5ded-9340-1f703007efc5 (int)
#             int
#           2c6cd5b8-2f45-5ce2-9e60-6b381d8c88c9 (int)
#             int
#           2c7b2887-e138-547b-804a-c02ce8c51de6 (int)
#             int
#           2f39f144-a02a-5017-a45a-4a3cfc2c7a36 (int)
#             int
#           3616d597-cbda-5839-9478-85b8e18d0011 (int)
#             int
#           373a5b22-c165-5533-aa12-893f13cc06d2 (int)
#             int
#           38513fa0-ea83-5642-8ecd-4f0b3daa6768 (int)
#             int
#           3b77bb52-4181-57f5-b3cd-f3a15b95aa29 (int)
#             int
#           3c0d065a-4aa4-55f4-bc11-bd326d23e5a6 (int)
#             int
#           3c25757c-4c47-5685-a14d-dcabb08fc79b (int)
#             int
#           3f736237-5bba-5b24-8fc5-ad279eec8c1b (int)
#             int
#           3f809288-0eaa-5f55-8144-483ed8ea810c (int)
#             int
#           404d6f98-eefb-5dea-8e81-aed2b5956437 (int)
#             int
#           41e69f7f-cf4a-5f5e-a5ce-5ef73900a9d9 (int)
#             int
#           46743f03-e0a4-5976-8d42-c3b698384b4e (int)
#             int
#           49383392-e722-56a9-afd0-c531ecb05310 (int)
#             int
#           49f64f3e-f0ff-5d4c-a730-5ea919857d82 (int)
#             int
#           4afd939d-f7b3-5807-bcc9-c2d7d4ac3ff9 (int)
#             int
#           50c75c75-4a07-5620-9798-5632fadf09e1 (int)
#             int
#           515fce14-605b-5768-b743-e8497b583d38 (int)
#             int
#           51bf24e5-bfa3-5262-b6c7-b7b6b6d09b83 (int)
#             int
#           52c9439c-c1b8-565e-bd8f-9e3203d7a051 (int)
#             int
#           546eac7c-1424-597d-ac13-bf8558e88fe3 (int)
#             int
#           5543c576-ef2b-59ac-878b-3aff199f27de (int)
#             int
#           556e35e6-ad67-51c6-8580-eda71597a507 (int)
#             int
#           56abb591-a158-5945-8dd6-97664f1c82cc (int)
#             int
#           56f4935b-f6c5-59b9-88bf-9bcce20247ce (int)
#             int
#           5a1f3fc3-e970-5408-94ef-e7c78e57000b (int)
#             int
#           5ac794d2-4c66-5332-afb1-54b24bc11823 (int)
#             int
#           5bd291f0-560a-5046-bd07-a91bd3004f2d (int)
#             int
#           5d53a06b-68a0-5d1a-a1a5-a676f16c23dd (int)
#             int
#           5e52c0be-d4fa-5f73-8d06-1080da4d0942 (int)
#             int
#           5ef80896-673a-548a-9eaa-05db2cbb07a0 (int)
#             int
#           5f06ccaf-7381-55e6-acb8-99c923d6a3bb (int)
#             int
#           5ff7b860-8e0f-51a3-a2db-9819417afd06 (int)
#             int
#           6022d604-c21f-599e-b65e-ff895bc51005 (int)
#             int
#           6028cab2-0478-584b-a880-8174a88eb188 (int)
#             int
#           60961bae-4655-5a6b-843d-f6180c2c310d (int)
#             int
#           668c64a2-cecb-5f48-af16-d7a64814d3e7 (int)
#             int
#           6b7fba1d-4937-5867-8a77-863ec30d432e (int)
#             int
#           6f08f7f6-ecfb-584f-ae7a-c6e4d9c4da35 (int)
#             int
#           6f9ae90a-5638-5b88-a3d7-ccea4372eb79 (int)
#             int
#           74fa21a6-66f3-5395-a95f-19e9f0b1d24b (int)
#             int
#           7cf5654d-d547-50ce-838a-75ff6045fd0f (int)
#             int
#           7dff9ddf-213e-593d-a007-a72cf6ff925e (int)
#             int
#           7e457744-dd60-5fd0-ae58-1718ef65c1a1 (int)
#             int
#           7f1bea50-20c0-51b3-8b2a-ac60f5d31133 (int)
#             int
#           80baae17-693b-5662-aad7-071f3b031fad (int)
#             int
#           814b54df-221c-5fdb-a516-0fbd438b57a7 (int)
#             int
#           81bcb781-c127-5def-8c17-ffcc2f09849a (int)
#             int
#           81daea6a-2735-5a46-a2da-b65a2ad5738f (int)
#             int
#           827e7d75-66de-5aee-bae3-517306eb4536 (int)
#             int
#           85245362-de1a-59fd-9f9a-d6a0c9522592 (int)
#             int
#           85f9f23a-a3ec-527f-aec2-1f0afaba0235 (int)
#             int
#           86b465df-0605-555c-aaa4-303f7e32d4d2 (int)
#             int
#           889dbfab-bcc2-5a94-ba57-01d229c6dccd (int)
#             int
#           890a9b49-9cea-500c-80c2-220e38b661fe (int)
#             int
#           8b56bd26-7d38-50f1-b4ce-5b6989081b83 (int)
#             int
#           8c265b98-5ca4-529e-a238-72d5de968dc4 (int)
#             int
#           8dfc67e9-8323-5d1f-9e25-9f9394abd5a0 (int)
#             int
#           9075708d-9c83-519c-aa81-465d35078747 (int)
#             int
#           952369f6-d553-558f-8385-5c219c66653b (int)
#             int
#           98becc43-123e-5e33-90f0-59318c221f4b (int)
#             int
#           9932f234-b27f-55df-96be-18b6583ba3df (int)
#             int
#           99be8d57-8eeb-5208-aa32-0a303e000795 (int)
#             int
#           9a14261a-b567-5429-a5ca-a913e15d8bf7 (int)
#             int
#           9a6b8e1e-1dc7-5807-bafd-bcd4fa1c6401 (int)
#             int
#           9ae3a282-1852-5b73-8c60-eabca0956349 (int)
#             int
#           9af574e4-dc6e-5246-8fe7-fee6c4c77a76 (int)
#             int
#           a139944e-bae3-523b-a29c-4aa3c544e532 (int)
#             int
#           a807430a-5a37-550c-989f-72d125d7b0c8 (int)
#             int
#           aa1c3b14-8a65-55ba-b741-68eef451a922 (int)
#             int
#           afdc12d3-7a55-5b55-b85c-12195718c79a (int)
#             int
#           b0a0f3ea-f483-53e3-ae41-bdb409141fdf (int)
#             int
#           b1c3860c-0def-5059-b183-d76ba9a1c93a (int)
#             int
#           b5bdfa8c-00ab-5b6a-b97a-ee77ffcbc4e9 (int)
#             int
#           bb6e511d-3e7f-5dd3-b40c-dbeb09c734f7 (int)
#             int
#           bba43f4e-a9eb-5c89-8389-5935a1fbd8b3 (int)
#             int
#           be665b02-1cf2-50c6-8861-85da921bc853 (int)
#             int
#           c3808d11-6614-57a9-b4bf-d276aa88f5a8 (int)
#             int
#           c5075bc5-ad52-5c59-b764-22bfc4b1c39c (int)
#             int
#           c620a95f-984f-5234-b8f3-a2e359972e85 (int)
#             int
#           c6eedc08-9b48-52b9-a9ec-bb0347fd3987 (int)
#             int
#           c879e36f-630c-573d-a6a6-25737805752f (int)
#             int
#           ca560ce6-8093-51e9-9b7f-2c11756d6516 (int)
#             int
#           cae5ac32-6265-5615-a060-21fb1a2dea5a (int)
#             int
#           cb833dcb-2d9b-528d-bf47-889102212f44 (int)
#             int
#           ceb02498-5932-532d-80f3-0f2d892aaed6 (int)
#             int
#           d1797b46-68c8-57b9-913e-cca4feb3dae8 (int)
#             int
#           d5124438-a5d4-5b3b-88af-d179f4b9c9af (int)
#             int
#           d899942a-ee50-5305-ab9c-5000f9bb3708 (int)
#             int
#           da8f1e81-fc1f-57f4-b4ec-0c5445a299e8 (int)
#             int
#           dec9c4f1-455e-56de-aad4-9a1d18cf5588 (int)
#             int
#           e5b81af3-5518-57ab-b42b-ab62e3732c72 (int)
#             int
#           efdd5367-9393-54c1-a6b8-c7810ee87ed5 (int)
#             int
#           f180c680-0dc9-5132-a713-65fdc4eefa75 (int)
#             int
#           f4ee3e9e-21da-5a63-8278-3efa59da7df3 (int)
#             int
#           fc96da15-9362-585a-b555-f7a7e5480e8b (int)
#             int
#           ff703e3a-4ea3-59d6-99e5-02c4db74f035 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#       uncommon (dict, len=3)
#         cards (dict, len=121)
#           01d6c876-b6e6-5534-8bef-42862a9cd839 (int)
#             int
#           01e48603-fbf2-5178-92d2-3d6c9944f4b5 (int)
#             int
#           06058b88-09c6-5475-a4b3-a72df2a7bea0 (int)
#             int
#           06af24c4-9cbe-5c8f-9c22-63273cf74ce6 (int)
#             int
#           0c960d75-fd2e-5a5a-ba78-58e10530fea0 (int)
#             int
#           0d2b2057-eb16-5435-aea9-61b3038ae9b2 (int)
#             int
#           0f3d794f-2e02-5fa8-b9a7-8ffa74f9615d (int)
#             int
#           0f95923c-e501-52ed-9666-5e73c531c642 (int)
#             int
#           126a046f-002e-50d8-ad2b-45973a624639 (int)
#             int
#           14878086-100b-5658-a753-571278cbb546 (int)
#             int
#           178922c9-620a-5eaa-8391-8216ec579232 (int)
#             int
#           18bacc5a-3ca0-5b72-bacb-ea98e6036c42 (int)
#             int
#           18db55ad-e62f-5c76-a6b8-743378d6ea38 (int)
#             int
#           1ebad7f2-d761-56b8-81ae-1e0225968026 (int)
#             int
#           1ee00edc-c888-5ad2-b591-e1810ca7ce59 (int)
#             int
#           1fcd5586-bd5b-5fe1-8875-c167a6137d39 (int)
#             int
#           20eaaca9-d27f-5521-a9f3-a6b1fcfab114 (int)
#             int
#           26180f1b-41a1-5fa5-9f6b-39ee08a1a203 (int)
#             int
#           261c0ce9-13d9-58e2-922b-d4068ff4d743 (int)
#             int
#           27745694-8868-5240-aa72-cdb326bd1e90 (int)
#             int
#           2d080e75-7e1b-5f75-9c8f-18d02a4710dd (int)
#             int
#           312306e1-001c-50b8-9a24-249bd40cfae3 (int)
#             int
#           31ecdb2e-eec0-56fb-9a12-7af9069f3673 (int)
#             int
#           3785490a-01f5-511d-b471-60b1209b3d4f (int)
#             int
#           3a76f884-3f71-5dbd-8ac8-6bb24e72704d (int)
#             int
#           3c265fdb-4a70-5ee7-ba8e-a67eac8d7b25 (int)
#             int
#           4429ce97-b78e-5bc4-bd34-a38b26794bdf (int)
#             int
#           4798151f-368c-5c06-910b-f0f63c2ec88b (int)
#             int
#           48792ac1-73cf-5a28-bf61-949b5950d881 (int)
#             int
#           4bdb6002-18d3-5a09-a94c-da7796980b83 (int)
#             int
#           4c1a672a-3089-563f-a852-9580a425dbf1 (int)
#             int
#           4c9c5ea9-5bca-5301-a0a2-2680fe75b04a (int)
#             int
#           4dd68de9-3c96-5c4f-b829-3c5c2c485c55 (int)
#             int
#           4e82f56f-3533-50af-9d10-b723005d5b35 (int)
#             int
#           4fa9bf42-9170-594e-bbf9-42111adea313 (int)
#             int
#           518754bb-441f-5f22-a106-377017a55ccc (int)
#             int
#           52d9f396-b080-5da2-b904-302c6f319f94 (int)
#             int
#           55492210-8ce6-553c-bdb7-573d824ca3c3 (int)
#             int
#           57aaebc1-850c-503d-9f6e-bb8d00d8bf7c (int)
#             int
#           5d45d146-5a42-502e-affb-71f3e81cf7e0 (int)
#             int
#           5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c (int)
#             int
#           60122d6f-448b-5df8-ac2a-8f5a1e841278 (int)
#             int
#           60c34bbe-d318-57e8-9226-c6f4af90c0c4 (int)
#             int
#           60f49caf-3583-5f85-b4b3-08dca73a8628 (int)
#             int
#           613639f1-7372-5b5c-9109-bef041108023 (int)
#             int
#           65e0dbca-81ed-538d-8f71-d5ddc5a927b9 (int)
#             int
#           6c08e1af-bbb8-5a03-b680-e00e45c68ace (int)
#             int
#           6c4d1103-3acd-5828-9bf7-77a0b1d405a4 (int)
#             int
#           6d030b32-0534-55c9-9c40-00bb59d4e164 (int)
#             int
#           6e2980cb-0c4a-521b-a99f-072533de225e (int)
#             int
#           6fd7afbb-7725-5f7a-91fe-cb578229971a (int)
#             int
#           7069fe50-d855-59ea-b445-e8068cda7559 (int)
#             int
#           70eb81fd-23fb-521a-9ac3-fae8f0ca5bf0 (int)
#             int
#           75578928-5ef3-5c91-87d8-e16191a1764e (int)
#             int
#           767ee0a4-a8fa-5bce-a948-0a067fa4ba89 (int)
#             int
#           76ddd7f5-1a84-55d5-98f5-4883c217e0d8 (int)
#             int
#           7db42d14-4950-5478-b87c-fbbd93889801 (int)
#             int
#           7fef665c-36a1-5f7a-9299-cf8938708710 (int)
#             int
#           8402d391-a810-5c04-af77-d3fb01dbacca (int)
#             int
#           855f7c1e-d582-5ae3-8f58-00a5c0d77c03 (int)
#             int
#           8d4f5d80-16ea-52cc-8201-93a46b803efb (int)
#             int
#           8d5006e3-45cb-5d9f-896d-83a22d86d53d (int)
#             int
#           8d805d91-280e-5c7e-81d2-2676b9ee93b5 (int)
#             int
#           8dfa8b47-af66-51df-9472-16c2bc4cf8f5 (int)
#             int
#           976585bc-fe72-56aa-b841-c4331d81655f (int)
#             int
#           9add78c6-3207-5f67-aa15-618adb14497b (int)
#             int
#           9ecee142-54dd-5a05-8e0d-702467b0ded5 (int)
#             int
#           9f55a614-586a-53dd-881a-d4a9648f2ba8 (int)
#             int
#           a1629073-cd64-5aa4-aca6-4d4e64dff8e2 (int)
#             int
#           a4bd6d9a-942d-53a3-8607-2354f86cc810 (int)
#             int
#           a563f008-ed9f-5fc4-b6aa-1e68d63cb814 (int)
#             int
#           a69b404f-144a-5317-b10e-7d9dce135b24 (int)
#             int
#           a9a74d88-7663-5419-a74c-5a28e8642b4f (int)
#             int
#           ab4f32a2-6671-5724-8ce9-6b721a5f2417 (int)
#             int
#           abb362ed-d21a-5b20-929a-9caca69b3dc8 (int)
#             int
#           ac084dab-6ac0-55fa-94b7-e009fede9012 (int)
#             int
#           ae68e914-6896-5ee8-af5f-8ea88f5e0200 (int)
#             int
#           aeb1b742-645c-5dab-ba9b-35d51649e074 (int)
#             int
#           b3de8302-e27e-5553-9ed6-f6a6f5fad14d (int)
#             int
#           b4f659b7-bef9-527b-95e8-55cc9c444ea4 (int)
#             int
#           b6b8b11d-0406-54e5-aed1-46d1588262e2 (int)
#             int
#           b8a68840-4044-52c0-a14e-0a1c630ba42c (int)
#             int
#           b9abc758-c583-5d39-b761-9e83496927aa (int)
#             int
#           bbea1480-68f2-51fb-8ac9-e7c7485f39fc (int)
#             int
#           bcc70712-566e-5a6f-8d73-f1ab87c57454 (int)
#             int
#           c19bcfc2-fc10-5040-8239-1c193098df47 (int)
#             int
#           c397d44d-ce30-511a-af0a-3c6a7f977df1 (int)
#             int
#           c7f34f83-c800-5987-8520-5ae1705871d9 (int)
#             int
#           cb865391-5b14-58ce-aa99-b36b83e6377f (int)
#             int
#           cdc0805a-73b1-5d98-bff3-4e06e6a1f036 (int)
#             int
#           cfa41bcc-edea-53e6-8aec-e7f9d5d23089 (int)
#             int
#           d089fdc1-4d21-58e8-b9c8-23d8b3191fe5 (int)
#             int
#           d2a33bcc-4679-54e9-90ad-1387ff8716e2 (int)
#             int
#           da0a5791-2fc2-53e4-bc8b-c4d8cd026ded (int)
#             int
#           dd3828b6-8e14-5f19-97f6-7ffdd9ffc91b (int)
#             int
#           de76ac44-6732-54a1-94a0-e87866b58aa0 (int)
#             int
#           e04a8147-589b-5b9d-8101-50073d47eb87 (int)
#             int
#           e0d42d12-40a7-54d5-b688-84841a8bc72c (int)
#             int
#           e2066f75-65de-5254-82f2-8e1f969bf31b (int)
#             int
#           e3f6afc6-060e-52e1-b537-3dc8039ca113 (int)
#             int
#           e54f8939-0853-5b0b-81b0-a29391bfb9e0 (int)
#             int
#           e553a0fb-cc04-551c-b0f7-f047cf0c2d0c (int)
#             int
#           e77dbe8c-5878-5881-b5f3-8203af673278 (int)
#             int
#           e9435188-40bd-54c7-938f-798459b038ed (int)
#             int
#           ea9feb69-1c09-5d99-a920-54760fd7fd0a (int)
#             int
#           ec5227b0-8cbd-5cad-a27e-32a798a3ae0a (int)
#             int
#           ec55586c-f4ae-5085-a6f0-20200af2ba76 (int)
#             int
#           ecf2b08e-7eca-5f13-a9f7-7a915ee259f5 (int)
#             int
#           eee00aa2-c730-5ff1-84a9-51d95a9fe180 (int)
#             int
#           eef8487a-450f-5e19-b9f1-2886839d02ec (int)
#             int
#           efe6103c-6a3e-5ed0-a689-81a2efe4273b (int)
#             int
#           f44e0c48-1740-5e18-859f-4e4615f3a3b1 (int)
#             int
#           f560811b-3c5d-5929-8b17-e9ae8730cec1 (int)
#             int
#           f6226c44-1f81-530a-9dda-8a63b412c727 (int)
#             int
#           f8084160-8edf-58fa-b453-81daf28278d0 (int)
#             int
#           f83c4766-5cf2-5ccb-943c-3c938b78c7b4 (int)
#             int
#           f90fe5cb-ee47-51f2-8a8c-3ced26f1b446 (int)
#             int
#           fac6ad26-f8c2-51bd-9f6a-a1b0940b4cef (int)
#             int
#           fd50dffd-b4d8-5956-9fec-b454fd1fef06 (int)
#             int
#           fe9187fa-cd14-5618-9a62-bcf18b523d84 (int)
#             int
#           fefca4a6-440f-56be-ba90-b8587c55d347 (int)
#             int
#         foil (bool)
#           bool
#         totalWeight (int)
#           int
#     sourceSetCodes (list, len=1)
#         str
# cards (list, len=510)
#     artist (str)
#       str
#     artistIds (list, len=1)
#         str
#     availability (list, len=2)
#         str
#     boosterTypes (list, len=1)
#         str
#     borderColor (str)
#       str
#     colorIdentity (list, len=1)
#         str
#     colors (list, len=1)
#         str
#     convertedManaCost (float)
#       float
#     edhrecRank (int)
#       int
#     finishes (list, len=1)
#         str
#     foreignData (list, len=8)
#         flavorText (str)
#           str
#         identifiers (dict, len=2)
#           multiverseId (str)
#             str
#           scryfallId (str)
#             str
#         language (str)
#           str
#         multiverseId (int)
#           int
#         name (str)
#           str
#         text (str)
#           str
#         type (str)
#           str
#     frameVersion (str)
#       str
#     hasFoil (bool)
#       bool
#     hasNonFoil (bool)
#       bool
#     identifiers (dict, len=15)
#       cardKingdomId (str)
#         str
#       cardsphereId (str)
#         str
#       deckboxId (str)
#         str
#       mcmId (str)
#         str
#       mcmMetaId (str)
#         str
#       mtgjsonFoilVersionId (str)
#         str
#       mtgjsonV4Id (str)
#         str
#       mtgoFoilId (str)
#         str
#       mtgoId (str)
#         str
#       multiverseId (str)
#         str
#       scryfallCardBackId (str)
#         str
#       scryfallId (str)
#         str
#       scryfallIllustrationId (str)
#         str
#       scryfallOracleId (str)
#         str
#       tcgplayerProductId (str)
#         str
#     isReprint (bool)
#       bool
#     keywords (list, len=1)
#         str
#     language (str)
#       str
#     layout (str)
#       str
#     legalities (dict, len=8)
#       commander (str)
#         str
#       duel (str)
#         str
#       legacy (str)
#         str
#       modern (str)
#         str
#       oathbreaker (str)
#         str
#       predh (str)
#         str
#       premodern (str)
#         str
#       vintage (str)
#         str
#     manaCost (str)
#       str
#     manaValue (float)
#       float
#     name (str)
#       str
#     number (str)
#       str
#     originalText (str)
#       str
#     power (str)
#       str
#     printings (list, len=3)
#         str
#     purchaseUrls (dict, len=3)
#       cardKingdom (str)
#         str
#       cardmarket (str)
#         str
#       tcgplayer (str)
#         str
#     rarity (str)
#       str
#     setCode (str)
#       str
#     sourceProducts (dict, len=1)
#       nonfoil (list, len=3)
#           str
#     subtypes (list, len=2)
#         str
#     supertypes (list, len=0)
#     text (str)
#       str
#     toughness (str)
#       str
#     type (str)
#       str
#     types (list, len=1)
#         str
#     uuid (str)
#       str
#     variations (list, len=1)
#         str
# cardsphereSetId (int)
#   int
# code (str)
#   str
# decks (list, len=17)
#     code (str)
#       str
#     commander (list, len=0)
#     displayCommander (list, len=0)
#     mainBoard (list, len=18)
#         count (int)
#           int
#         uuid (str)
#           str
#     name (str)
#       str
#     planes (list, len=0)
#     releaseDate (str)
#       str
#     schemes (list, len=0)
#     sealedProductUuids (list, len=1)
#         str
#     sideBoard (list, len=0)
#     type (str)
#       str
# isFoilOnly (bool)
#   bool
# isOnlineOnly (bool)
#   bool
# keyruneCode (str)
#   str
# languages (list, len=9)
#     str
# mcmId (int)
#   int
# mcmName (str)
#   str
# mtgoCode (str)
#   str
# name (str)
#   str
# releaseDate (str)
#   str
# sealedProduct (list, len=19)
#     category (str)
#       str
#     contents (dict, len=1)
#       sealed (list, len=1)
#           count (int)
#             int
#           name (str)
#             str
#           set (str)
#             str
#           uuid (str)
#             str
#     identifiers (dict, len=8)
#       abuId (str)
#         str
#       cardKingdomId (str)
#         str
#       cardtraderId (str)
#         str
#       csiId (str)
#         str
#       mcmId (str)
#         str
#       scgId (str)
#         str
#       tcgplayerProductId (str)
#         str
#       tntId (str)
#         str
#     name (str)
#       str
#     purchaseUrls (dict, len=2)
#       cardKingdom (str)
#         str
#       tcgplayer (str)
#         str
#     subtype (str)
#       str
#     uuid (str)
#       str
# tcgplayerGroupId (int)
#   int
# tokenSetCode (str)
#   str
# tokens (list, len=6)
#     artist (str)
#       str
#     artistIds (list, len=1)
#         str
#     availability (list, len=1)
#         str
#     boosterTypes (list, len=1)
#         str
#     borderColor (str)
#       str
#     colorIdentity (list, len=1)
#         str
#     colors (list, len=1)
#         str
#     finishes (list, len=1)
#         str
#     frameVersion (str)
#       str
#     hasFoil (bool)
#       bool
#     hasNonFoil (bool)
#       bool
#     identifiers (dict, len=8)
#       mcmId (str)
#         str
#       mcmMetaId (str)
#         str
#       mtgjsonV4Id (str)
#         str
#       scryfallCardBackId (str)
#         str
#       scryfallId (str)
#         str
#       scryfallIllustrationId (str)
#         str
#       scryfallOracleId (str)
#         str
#       tcgplayerProductId (str)
#         str
#     isFullArt (bool)
#       bool
#     isReprint (bool)
#       bool
#     language (str)
#       str
#     layout (str)
#       str
#     name (str)
#       str
#     number (str)
#       str
#     power (str)
#       str
#     promoTypes (list, len=1)
#         str
#     relatedCards (dict, len=1)
#       reverseRelated (list, len=73)
#           str
#     reverseRelated (list, len=73)
#         str
#     setCode (str)
#       str
#     subtypes (list, len=1)
#         str
#     supertypes (list, len=0)
#     toughness (str)
#       str
#     type (str)
#       str
#     types (list, len=2)
#         str
#     uuid (str)
#       str
# totalSetSize (int)
#   int
# type (str)
#   str

# %%
data__all_printings['data']['10E']['booster']['draft'].keys()
# Out:
# dict_keys(['boosters', 'boostersTotalWeight', 'name', 'sheets', 'sourceSetCodes'])

# %%
data__all_printings['data']['10E']['booster']['draft']['boostersTotalWeight']
# Out:
# 2401000
